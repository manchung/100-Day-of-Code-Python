# %%
import pandas as pd
df = pd.read_csv('./salaries_by_college_major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
clean_df = df.dropna()
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
clean_df['Starting Median Salary'].max()
# Out:
# 74300.0

# %%
clean_df['Undergraduate Major'][clean_df['Starting Median Salary'] == clean_df['Starting Median Salary'].max()]
# Out:
# 43    Physician Assistant
# Name: Undergraduate Major, dtype: object

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
clean_df['Mid-Career Median Salary'].max()
# Out:
# 107000.0

# %%
clean_df['Mid-Career Median Salary'].idxmax()
# Out:
# 8

# %%
clean_df['Undergraduate Major'][8]
# Out:
# 'Chemical Engineering'

# %%
clean_df[clean_df['Mid-Career Median Salary']==clean_df['Mid-Career Median Salary'].min()]
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 18           Education                 34900.0                   52000.0
# 47            Religion                 34100.0                   52000.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 18                            29300.0                           102000.0  HASS
# 47                            29700.0                            96400.0  HASS

# %%
clean_df[clean_df['Starting Median Salary'] == clean_df['Starting Median Salary'].min()]
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 49                            31000.0                            96400.0  HASS

# %%
clean_df['Spread'] = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(1, 'Spread', clean_df['Spread'])
clean_df.head()
# Out:
# /var/folders/91/bc1s7yq104z_xqw7fd4xx2kh0000gn/T/ipykernel_41269/3863802816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['Spread'] = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/91/bc1s7yq104z_xqw7fd4xx2kh0000gn/T/ipykernel_41269/3863802816.py in ?()
#       1 clean_df['Spread'] = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
# ----> 2 clean_df.insert(1, 'Spread', clean_df['Spread'])
#       3 clean_df.head()
#
# ...

# %%
clean_df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group    Spread
# 0  Business  109800.0
# 1      STEM   96700.0
# ...

# %%
clean_df.sort_values('Spread', ascending=True, inplace=True)
clean_df.head(10)
# Out:
# /var/folders/91/bc1s7yq104z_xqw7fd4xx2kh0000gn/T/ipykernel_41269/341183995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.sort_values('Spread', ascending=True, inplace=True)
#            Undergraduate Major  Starting Median Salary  \
# 40                     Nursing                 54200.0
# 43         Physician Assistant                 74300.0
# 41                   Nutrition                 39900.0
# 49                     Spanish                 34000.0
# 27  Health Care Administration                 38800.0
# 47                    Religion                 34100.0
# 23                    Forestry                 39100.0
# 32             Interior Design                 36100.0
# 18                   Education                 34900.0
# ...

# %%
clean_df.sort_values('Mid-Career 90th Percentile Salary', ascending=False, inplace=True)
clean_df.head(10)
# Out:
# /var/folders/91/bc1s7yq104z_xqw7fd4xx2kh0000gn/T/ipykernel_41269/3190275371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.sort_values('Mid-Career 90th Percentile Salary', ascending=False, inplace=True)
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17               Economics              $50,100.00                $98,600.00
# 22                 Finance              $47,900.00                $88,300.00
# 8     Chemical Engineering              $63,200.00               $107,000.00
# 37                    Math              $45,400.00                $92,400.00
# 44                 Physics              $50,300.00                $97,300.00
# 36               Marketing              $40,800.00                $79,600.00
# ...

# %%
clean_df[['Starting Median Salary', 'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary', 'Mid-Career 90th Percentile Salary', 'Group']].groupby('Group').mean()
# Out:
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business              $44,633.33                $75,083.33
# HASS                  $37,186.36                $62,968.18
# STEM                  $53,862.50                $90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                         $43,566.67                        $147,525.00
# HASS                             $34,145.45                        $129,363.64
# STEM                             $56,025.00                        $157,625.00

# %%
pd.options.display.float_format = '${:,.2f}'.format

# %%
df = pd.read_csv('payscale.csv')

# %%
df.head()
# Out:
#                                               Major  Early Career Pay  \
# 0                             Petroleum Engineering             98100
# 1      Operations Research & Industrial Engineering            101200
# 2  Electrical Engineering & Computer Science (EECS)            128500
# 3                                Interaction Design             77400
# 4                                  Building Science             71100
#
#    Mid Career Pay
# 0          212100
# 1          202600
# 2          192300
# 3          178800
# 4          172400

# %%
df[df['Mid Career Pay'] == df['Mid Career Pay'].max()]
# Out:
#                    Major  Early Career Pay  Mid Career Pay
# 0  Petroleum Engineering             98100          212100

# %%
sorted_df = df.sort_values('Mid Career Pay', ascending=False)

# %%
sorted_df.head(10)
# Out:
#                                               Major  Early Career Pay  \
# 0                             Petroleum Engineering             98100
# 1      Operations Research & Industrial Engineering            101200
# 2  Electrical Engineering & Computer Science (EECS)            128500
# 3                                Interaction Design             77400
# 4                                  Building Science             71100
# 5                  Applied Economics and Management             81200
# 6                             Actuarial Mathematics             71200
# 7                     Optical Science & Engineering             81500
# 8                            Quantitative Economics             78400
# 9                               Operations Research             94900
#
#    Mid Career Pay
# 0          212100
# 1          202600
# 2          192300
# 3          178800
# 4          172400
# 5          169300
# 6          167500
# 7          166400
# 8          165100
# ...
